# %%
# !pip install pillow
from PIL import Image
import os
dataset_path=r"C:\Users\91914\OneDrive\Apps\Desktop\gca\TrashType_Image_Dataset"
garbage_labels=os.listdir(dataset_path)
print('identified labels')
for label in garbage_labels:
    print('>>',label.capitalize())
    label_path=os.path.join(dataset_path,label)
    if os.path.isdir(label_path):
        print('This is indeed a folder',label_path)
        image_files=[]
    for file in os.listdir(label_path):
        if file.lower().endswith(('.jpg','.jpeg','.png')):
            image_files.append(file)
        print(label.capitalize() + " ➜ " + str(len(image_files)) + " images")
for label in garbage_labels:
    label_path = os.path.join(dataset_path, label)
    if os.path.isdir(label_path):
        if os.path.isdir(label_path):
            files = os.listdir(label_path)
            if len(files) > 0:
                image_name = files[0]
                image_path = os.path.join(label_path, image_name)
                img = Image.open(image_path)
                print(label.capitalize(), "- Size:", img.size)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# identified labels
# >> Cardboard
# This is indeed a folder C:\Users\91914\OneDrive\Apps\Desktop\gca\TrashType_Image_Dataset\cardboard
# Cardboard ➜ 1 images
# Cardboard ➜ 2 images
# Cardboard ➜ 3 images
# Cardboard ➜ 4 images
# Cardboard ➜ 5 images
# Cardboard ➜ 6 images
# Cardboard ➜ 7 images
# Cardboard ➜ 8 images
# Cardboard ➜ 9 images
# Cardboard ➜ 10 images
# Cardboard ➜ 11 images
# Cardboard ➜ 12 images
# Cardboard ➜ 13 images
# Cardboard ➜ 14 images
# Cardboard ➜ 15 images
# Cardboard ➜ 16 images
# Cardboard ➜ 17 images
# Cardboard ➜ 18 images
# Cardboard ➜ 19 images
# Cardboard ➜ 20 images
# Cardboard ➜ 21 images
# Cardboard ➜ 22 images
# Cardboard ➜ 23 images
# Cardboard ➜ 24 images
# Cardboard ➜ 25 images
# >> Glass
# This is indeed a folder C:\Users\91914\OneDrive\Apps\Desktop\gca\TrashType_Image_Dataset\glass
# Glass ➜ 1 images
# Glass ➜ 2 images
# Glass ➜ 3 images
# Glass ➜ 4 images
# ...

# %%
# !pip install pillow 
import sys
# !{sys.executable} -m pip install tensorflow
import os
from PIL import Image
src = r"C:\Users\91914\OneDrive\Apps\Desktop\gca\TrashType_Image_Dataset"
dst = r"C:\Users\91914\OneDrive\Apps\Desktop\gca\TrashTypr_Image_resized"
size = (224, 224)

os.makedirs(dst, exist_ok=True)

for label in os.listdir(src):
    src_folder = os.path.join(src, label)
    dst_folder = os.path.join(dst, label)

    if os.path.isdir(src_folder):
        os.makedirs(dst_folder, exist_ok=True)

        for name in os.listdir(src_folder):
            if name.lower().endswith(('.jpg', '.jpeg', '.png')):
                try:
                    print(f"Processing {label} - {img}")
                    img = Image.open(os.path.join(src_folder, name))
                    img.resize(size).save(os.path.join(dst_folder, name))
                except:
                    pass
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Processing cardboard - <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x384 at 0x1530631BCE0>
# Processing cardboard - <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x384 at 0x15306332150>
# Processing cardboard - <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x384 at 0x15306CB21B0>
# Processing cardboard - <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x384 at 0x1530844C530>
# Processing cardboard - <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x384 at 0x153062EFAD0>
# Processing cardboard - <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x384 at 0x153071F1EB0>
# Processing cardboard - <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x384 at 0x15305DD7A10>
# ...

# %%
import os
from PIL import Image

src = r"C:/Users/91914/OneDrive/Apps/Desktop/gca/TrashType_Image_Dataset"
dst = r"C:/Users/91914/OneDrive/Apps/Desktop/gca/TrashType_Image_Resized"
size = (224, 224)

os.makedirs(dst, exist_ok=True)

for label in os.listdir(src):
    src_folder = os.path.join(src, label)
    dst_folder = os.path.join(dst, label)

    if os.path.isdir(src_folder):
        os.makedirs(dst_folder, exist_ok=True)

        for name in os.listdir(src_folder):
            if name.lower().endswith(('.jpg', '.jpeg', '.png')):
                try:
                    print(f"Resizing {label} - {name}")
                    img = Image.open(os.path.join(src_folder, name))
                    img.resize(size).save(os.path.join(dst_folder, name))
                except:
                    pass
# Out:
# Resizing cardboard - cardboard_001.jpg
# Resizing cardboard - cardboard_026.jpg
# Resizing cardboard - cardboard_033.jpg
# Resizing cardboard - cardboard_034.jpg
# Resizing cardboard - cardboard_035.jpg
# Resizing cardboard - cardboard_036.jpg
# Resizing cardboard - cardboard_045.jpg
# Resizing cardboard - cardboard_046.jpg
# Resizing cardboard - cardboard_047.jpg
# Resizing cardboard - cardboard_048.jpg
# Resizing cardboard - cardboard_049.jpg
# Resizing cardboard - cardboard_050.jpg
# Resizing cardboard - cardboard_070.jpg
# Resizing cardboard - cardboard_096.jpg
# Resizing cardboard - cardboard_097.jpg
# Resizing cardboard - cardboard_098.jpg
# Resizing cardboard - cardboard_099.jpg
# Resizing cardboard - cardboard_100.jpg
# Resizing cardboard - cardboard_101.jpg
# Resizing cardboard - cardboard_194.jpg
# Resizing cardboard - cardboard_195.jpg
# Resizing cardboard - cardboard_340.jpg
# Resizing cardboard - cardboard_341.jpg
# Resizing cardboard - cardboard_342.jpg
# ...
